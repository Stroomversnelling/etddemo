# %% [markdown]
# # Mapping raw household sensor data to the Energy Transition Dataset
#
# This notebook demonstrates the code required to map raw household sensor data to the Energy Transition Dataset Data Model.
#
# This notebook should be helpful to both potential data suppliers, such as social housing corporations, building companies and monitoring companies, who would like to understand the impact of their installations at neighborhood level. After reading this notebook, you should be ready to submit data.
#
# This diagram provides an overview of the process. Most steps require some level of manual intervention. Where there is code that supports the process, the function is also provided. There are two main actors:
#
# - The data supplier
# - The data processor, in this example it is the Stroomversnelling (BSV)
#
# ```mermaid
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
# sequenceDiagram
#     participant Supplier
#     participant DataProcessorBSV
#
#     Supplier->Supplier: Acquire raw data & prepare metadata <br>(Use Excel Template)
#     Supplier->Supplier: Validate & check required columns
#     Supplier->Supplier: Perform initial data transformations <br>(conversion)
#
#     Supplier->DataProcessorBSV: Submit data for processing
#
#     DataProcessorBSV->DataProcessorBSV: Validate data against ETD model <br>`load_etdmodel()`
#     DataProcessorBSV->DataProcessorBSV: Initial statistical column check <br>`collect_column_stats()`
#     DataProcessorBSV->DataProcessorBSV: Inspect data completeness <br>(Missing Values & Intervals)
#     DataProcessorBSV->DataProcessorBSV: Calculate differences <br>`add_diff_columns()`
#     DataProcessorBSV->DataProcessorBSV: Validate cumulative data <br>`validate_cumulative_variables()`
#     DataProcessorBSV->DataProcessorBSV: Final statistical column check <br>`get_mapped_data_stats()`
#     Note right of DataProcessorBSV: Send feedback if needed
#
#     DataProcessorBSV-->Supplier: Feedback to revise data
#
#     Supplier->Supplier: Revise data & resubmit
#
#     Supplier->DataProcessorBSV: Submit revised data
#
#     DataProcessorBSV->DataProcessorBSV: Update BSV metadata <br>`update_index()`, <br>`add_supplier_metadata_to_index()`
#     DataProcessorBSV->DataProcessorBSV: Manage data index & aggregate data
#     DataProcessorBSV-->Supplier: Process complete
# ```
#
# ## Prepping the required environment
#
# In order to prepare raw data, we will first check the Energy Transition Dataset Model. In order to do this, and most steps in this notebook, we will use the `etdmap` package. This is documented in all detail at [stroomversnelling.github.io/etdmap](https://stroomversnelling.github.io/etdmap). Other ETD packages are found at [stroomversnelling.github.io/](https://stroomversnelling.github.io/) but will not be required for this demonstration.
#
# First we can install the requirements using pip:
#
# ```bash
# pip install git+https://github.com/Stroomversnelling/etdmap.git
# ```
#
# ## Configuration
#
# We will need to configure some variables in order to run this example. First of all, we need to provide the folder that contains the raw data.
#
# ```python
# import etdmap
#
# etdmap.options.mapped_folder_path = "../../demodata/mapped" # change to path to folder where you would like to store mapped data
# etdmap.options.bsv_metadata_file = "../../demodata/processor_metadata.xlsx" # change to path to the Excel file with the data processor metadata (BSV in this case)
#
# ```
#
# ## Prepping raw data
#
# - The data supplier is always asked to prepare an Excel sheet with the units/households that are included in the provided data.
# - The example Excel sheet can be found in the same folder as this notebook.
# - In addition, the data supplier will prepare a single data file (parquet format) per household.
# - We will use the example of the data received from Watch-E.
# - The columns did not match the data model so we will prepare a dictionary to rename the columns later.
#
# ## Prepping the data processor metadata
#
# The data processor also must create a metadata file. This one will initially have no records. See the example. The first row in the example can be deleted before starting.

# %%
import etdmap

watch_e_raw_data_folder_path = "../../demodata/watch_e" # this is our demo dataset we will be mapping
watch_e_metadata_file = "../../demodata/watch_e_metadata.xlsx"

# Set the standard etdmap options
etdmap.options.mapped_folder_path = "../../demodata/mapped" # change to path to folder where you would like to store mapped data
etdmap.options.bsv_metadata_file = "../../demodata/bsv_metadata.xlsx" # change to path to the Excel file with the data processor metadata (BSV is the data processor in this case)

# %% [markdown]
# ## Load the data model and map to raw data columns
#
# First we will check the columns in the raw data and columns in the data model. Based on that we'll create a dictionary mapping the raw data columns to the columns of our model. In this case, we do not need to do any unit conversions. We can review the model columns that are required using the `load_etdmodel()` function in the `data_model` module.
#
#
# ```mermaid
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
# sequenceDiagram
#     participant Supplier
#     participant DataProcessorBSV
#
#     Supplier->Supplier: Acquire raw data & prepare metadata <br>(Use Excel Template)
#     Supplier->Supplier: Validate & check required columns
#     Supplier->Supplier: Perform initial data transformations <br>(conversion)
#
#     Supplier->DataProcessorBSV: Submit data for processing
#
#     DataProcessorBSV->DataProcessorBSV: Validate data against ETD model <br>`load_etdmodel()`
#     DataProcessorBSV->DataProcessorBSV: Initial statistical column check <br>`collect_column_stats()`
#
# ```

# %%
from etdmap.data_model import load_etdmodel

load_etdmodel().head()
# Out:
#    Entiteit             Variabele  Key Type variabele Vereist     Resolutie  \
# 0  Metadata          ProjectIdBSV  nee        integer     nee  vaste waarde
# 1  Metadata  ProjectIdLeverancier  nee         string      ja  vaste waarde
# 2  Metadata             HuisIdBSV  nee        integer     nee  vaste waarde
# 3  Metadata     HuisIdLeverancier   ja         string      ja  vaste waarde
# 4  Metadata           Weerstation  nee         string      ja  vaste waarde
#
#            Wie vult?               Bron  \
# 0  Stroomversnelling  Stroomversnelling
# 1    Dataleverancier    Dataleverancier
# 2  Stroomversnelling  Stroomversnelling
# 3    Dataleverancier    Dataleverancier
# 4    Dataleverancier    Dataleverancier
#
#                                Definitie AVG gevoelig
# 0  code toegekend door Stroomversnelling          nee
# 1    code toegekend door dataleverancier           ja
# 2  code toegekend door Stroomversnelling          nee
# 3    code toegekend door dataleverancier           ja
# 4      dichtstbijzijnde KNMI weerstation          nee

# %%
# Define a dictionary to map the raw data columns to the mapped data

watch_e_mapping_dict = {
    "ReadingDate": "ReadingDate",
    "Elektriciteit netgebruik (hoog) [kWh]": "ElektriciteitNetgebruikHoog",
    "Elektriciteit netgebruik (laag) [kWh]": "ElektriciteitNetgebruikLaag",
    "Elektriciteit teruglevering (hoog) [kWh]": "ElektriciteitTerugleveringHoog",
    "Elektriciteit teruglevering (laag) [kWh]": "ElektriciteitTerugleveringLaag",
    "Elektriciteitsgebruik WTW [kWh]": "ElektriciteitsgebruikWTW",
    # There is a variable for both the heat pump inside and outside which we will combine in the script:
    "Elektriciteitsgebruik warmtepomp binnen [kWh]": "ElektriciteitsgebruikWarmtepomp_binnen", 
    "Elektriciteitsgebruik warmtepomp buiten [kWh]": "ElektriciteitsgebruikWarmtepomp_buiten",
    "Elektriciteitsgebruik warmtepomp [kWh]": "ElektriciteitsgebruikWarmtepomp",
    "Elektriciteitsgebruik E.EL.Warmtepomp [kWh]": "ElektriciteitsgebruikBooster",
    "Elektriciteitsgebruik boiler [kWh]": "ElektriciteitsgebruikBoilervat",
    "Elektriciteitsgebruik Radiator [kWh]": "ElektriciteitsgebruikRadiator",
    "Temperatuur warm tapwater [°C]": "TemperatuurWarmTapwater",
    "Temperatuur woonkamer [°C]": "TemperatuurWoonkamer",
    "Warmteproductie warmtepomp [GJ]": "WarmteproductieWarmtepomp",
    "Watergebruik warm [liter]": "WatergebruikWarmTapwater",
    "Zon-opwek Momentaan [kW]": "Zon-opwekMomentaan",
    "Zon-opwek Totaal [kWh]": "Zon-opwekTotaal",
    "CDR-RH CO2 [ppm]": "CO2",
    "CDR-RH 1 CO2 [ppm]": "CO2",
    "CDR-RH Luchtvochtigheid [%]": "Luchtvochtigheid",
    "CDR-RH Temperatuur [grC]": "CDR-RH Temperatuur [grC]",
    "Gasgebruik [m3]": "Gasgebruik",
    "WarmteProductie CV Warm water [GJ]": "WarmteproductieWarmTapwater",
    "Luchtvochtigheid woonkamer [%]": "Luchtvochtigheid",
    "CDR-RH 1 Luchtvochtigheid": "Luchtvochtigheid",
    "Warmteproductie CV [GJ]": "WarmteproductieCV",
}

# %% [markdown]
# ### Examine the raw data variable statistiscs
#
# We will now examine the raw variables by looping through the raw data files and collecting statistics.

# %%
from etdmap import mapping_helpers
import pandas as pd

df_raw_stats = mapping_helpers.get_raw_data_stats(
    raw_data_folder_path = watch_e_raw_data_folder_path, 
    multi = True, 
    max_workers = 10
)

df_raw_stats.head()
# Out:
#                                  Identifier  \
# 0  024b35f544c0de4c78fbfa4b401126dc.parquet
# 1  024b35f544c0de4c78fbfa4b401126dc.parquet
# 2  024b35f544c0de4c78fbfa4b401126dc.parquet
# 3  024b35f544c0de4c78fbfa4b401126dc.parquet
# 4  024b35f544c0de4c78fbfa4b401126dc.parquet
#
#                                      column            type   count  missing  \
# 0                               ReadingDate  datetime64[ns]  105093        0
# 1     Elektriciteit netgebruik (hoog) [kWh]         float64  105093        0
# 2     Elektriciteit netgebruik (laag) [kWh]         float64  105093        0
# 3  Elektriciteit teruglevering (hoog) [kWh]         float64  105093        0
# 4  Elektriciteit teruglevering (laag) [kWh]         float64  105093        0
#
#    errors                  min                  max         mean    median  \
# 0       0  2023-01-01 00:00:00  2024-01-01 00:00:00          NaN       NaN
# 1       0               822.16             1364.201  1077.002484  1067.561
# 2       0              1157.82             1985.089  1558.287115  1564.534
# 3       0              3397.66             5960.516  4755.762583  4830.055
# 4       0              2268.15             3382.208  2862.596044  2949.556
#
#         iqr  quantile_25  quantile_75  top5
# 0       NaN          NaN          NaN  None
# 1   131.921     1007.248     1139.169  None
# 2   299.327     1407.841     1707.168  None
# 3  2118.687     3686.697     5805.384  None
# 4   935.412     2382.013     3317.425  None

# %%
df_raw_stats[df_raw_stats['missing']>0].head()
# Out:
#                                   Identifier  \
# 5   024b35f544c0de4c78fbfa4b401126dc.parquet
# 10  024b35f544c0de4c78fbfa4b401126dc.parquet
# 19  0290e5ebef786f7d3937c6ea53f9ef56.parquet
# 22  0290e5ebef786f7d3937c6ea53f9ef56.parquet
# 25  0290e5ebef786f7d3937c6ea53f9ef56.parquet
#
#                                 column     type   count  missing  errors  \
# 5      Elektriciteitsgebruik WTW [kWh]  float64    8759    96334   96334
# 10           Watergebruik warm [liter]  float64    8759    96334   96334
# 19  Elektriciteitsgebruik boiler [kWh]  float64  105107        2       2
# 22      Luchtvochtigheid woonkamer [%]  float64  105005      104     104
# 25      Temperatuur warm tapwater [°C]  float64  104968      141     141
#
#        min        max         mean    median       iqr  quantile_25  \
# 5    74.68     118.83    96.308056    97.870    24.850        83.85
# 10  6519.0  11829.001  9149.792177  9184.001  2336.001      8004.00
# 19  264.99      601.1   433.210482   436.770   165.060       351.10
# 22    41.3       79.2    59.553509    59.100    11.300        54.30
# 25   19.16      64.07    31.340442    27.280    13.770        23.43
#
#     quantile_75  top5
# 5       108.700  None
# 10    10340.001  None
# 19      516.160  None
# 22       65.600  None
# 25       37.200  None

# %% [markdown]
# ## Mapping the raw data to the data model
#
# Here we will go through all the following steps
#
# ```mermaid
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
# sequenceDiagram
#     participant Supplier
#     participant DataProcessorBSV
#
#     DataProcessorBSV->DataProcessorBSV: Calculate differences <br>`add_diff_columns()`
#     DataProcessorBSV->DataProcessorBSV: Validate cumulative data <br>`validate_cumulative_variables()`
#
# ```

# %%
import os
import logging

import watch_e_helpers

from etdmap.record_validators import record_flag_conditions

from etdmap.index_helpers import get_household_id_pairs, read_index, update_index
from etdmap.mapping_helpers import (
    rearrange_model_columns,
    add_diff_columns,
    model_column_type,
    ensure_intervals,
    fill_down_infrequent_devices,
)


# load the index of existing mapped data files
index_df, index_path = read_index()

# Generate a dictionary of new household ids `HuisIdBSV` for our index mapped
# the list of files in our raw data folder (one file per household)
household_id_pairs = get_household_id_pairs(
    index_df, watch_e_raw_data_folder_path, "Watch-E", watch_e_helpers.list_files_watch_e
)

# Loop through the files and load the raw data
for huis_code, file_name in household_id_pairs:

    # Set the file paths for the raw data files and mapped data files to be generated
    file_path = os.path.join(watch_e_raw_data_folder_path, file_name)
    new_file_path = os.path.join(
        etdmap.options.mapped_folder_path, f"household_{huis_code}_table.parquet"
    )

    # Load the raw data
    watche_df = pd.read_parquet(file_path)

    # Rename columns using the Watch-E dictionary
    watche_df.rename(columns=watch_e_mapping_dict, inplace=True)

    # Correct a specific issue Watch-E data during the summer time switch
    watche_df = watch_e_helpers.correct_summer_time_with_timezone_check_watch_e(
        watche_df, "ReadingDate"
    )

    # Ensure that the DataFrame has a consistent number of records and expected time intervals
    watche_df = ensure_intervals(watche_df)

    # Ensure all expected columns are present and combine the interior and exterior heatpump columns
    watche_df = watch_e_helpers.combine_inside_outside_heatpumps(watche_df, watch_e_mapping_dict, model_column_type, huis_code, file_name)

    # Sort our columns to match the data model and add empty columns when the column is 
    # not provided
    watche_df = rearrange_model_columns(
        household_df=watche_df, add_columns=True, context=f"{huis_code}/{file_name}"
    )

    # Certain devices do not report cumulative data when not operational and need to be 
    # filled down with some assumptions
    watche_df = fill_down_infrequent_devices(
        df=watche_df,
        columns=(
            'ElektriciteitsgebruikBoilervat',
            'ElektriciteitsgebruikRadiator',
            'ElektriciteitsgebruikBooster',
        )
    )

    # Add new difference columns to show the incremental change in cumulative columns in
    # each time period
    watche_df = add_diff_columns(watche_df, context=f"{huis_code}/{file_name}")

    # Add validation columns to the household to check threshholds and other issues
    for flag, condition in record_flag_conditions.items():
        try:
            watche_df[flag] = condition(watche_df)
        except Exception as e:
            logging.error(
                f"Error validating with {flag} for household {huis_code} / {file_name}: {e}",
                exc_info=True,
            )
            watche_df[flag] = pd.NA

    # Save the mapped data file for the household
    watche_df.to_parquet(new_file_path, engine="pyarrow")

    # Update the index with the new household
    index_df = update_index(
        index_df, 
        new_entry={"HuisIdLeverancier": file_name.replace(".parquet", ""), "HuisIdBSV": huis_code}, 
        data_provider="Watch-E"
    )
# Out:
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-04-08 16:00:00 (1680969600.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-04-08 16:00:00 (1680969600.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Group has a gap of 0 days 01:25:00 > allowed (0 days 01:00:00) starting at 2023-04-08 15:50:00 (1680969000.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:1/024b35f544c0de4c78fbfa4b401126dc.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitsgebruikBoilervat' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Column 'ElektriciteitsgebruikWTW' in group has less than 90.0% non-NA values.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-04-29 07:00:00 (1682751600.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:2/0290e5ebef786f7d3937c6ea53f9ef56.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:3/068690b7864a3d0feff39bea2e5556df.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'CO2' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 18:00:00 > allowed (0 days 01:00:00) starting at 2023-12-03 17:00:00 (1701622800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 18:00:00 > allowed (0 days 01:00:00) starting at 2023-12-03 17:00:00 (1701622800.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Group has a gap of 0 days 16:15:00 > allowed (0 days 01:00:00) starting at 2023-12-03 16:05:00 (1701619500.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:4/08552726673ae0cb8ec73be7e4a75f9d.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Column 'ElektriciteitsgebruikWTW' in group has less than 90.0% non-NA values.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:05:00 > allowed (0 days 01:00:00) starting at 2023-04-02 05:25:00 (1680413100.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 07:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 14:00:00 (1696428000.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Group has a gap of 0 days 06:00:00 > allowed (0 days 01:00:00) starting at 2023-10-04 13:55:00 (1696427700.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:5/0bf7095bf31ef4edc72e1e8353e68dbf.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitsgebruikBoilervat' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:40:00 > allowed (0 days 01:00:00) starting at 2023-04-25 10:30:00 (1682418600.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:40:00 > allowed (0 days 01:00:00) starting at 2023-04-25 10:30:00 (1682418600.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:40:00 > allowed (0 days 01:00:00) starting at 2023-04-25 10:30:00 (1682418600.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:40:00 > allowed (0 days 01:00:00) starting at 2023-04-25 10:30:00 (1682418600.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'ElektriciteitsgebruikWTW' in group has less than 90.0% non-NA values.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:45:00 > allowed (0 days 01:00:00) starting at 2023-12-02 14:05:00 (1701525900.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'WarmteproductieWarmtepomp' in group has less than 90.0% non-NA values.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Column 'WatergebruikWarmTapwater' in group has less than 90.0% non-NA values.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Group has a gap of 0 days 01:40:00 > allowed (0 days 01:00:00) starting at 2023-04-25 10:30:00 (1682418600.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:6/0e52f3fbd38a15df4058d4e4f9788ab5.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'CO2' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 04:00:00 > allowed (0 days 01:00:00) starting at 2023-01-17 12:00:00 (1673956800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:40:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:25:00 (1673954700.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 04:00:00 > allowed (0 days 01:00:00) starting at 2023-01-17 12:00:00 (1673956800.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Group has a gap of 0 days 02:35:00 > allowed (0 days 01:00:00) starting at 2023-01-17 11:20:00 (1673954400.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:7/0eb53449d17ca3be8d4d602af924d10d.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'ElektriciteitsgebruikRadiator' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'CO2' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 11:00:00 > allowed (0 days 01:00:00) starting at 2023-01-05 22:00:00 (1672956000.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 11:00:00 > allowed (0 days 01:00:00) starting at 2023-01-05 22:00:00 (1672956000.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Group has a gap of 3 days 10:15:00 > allowed (0 days 01:00:00) starting at 2023-01-05 21:30:00 (1672954200.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:8/1392bfdbbbc3870c65e405fb28641570.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# ERROR:root:9/13bdb9310675508db0e411a38d5e7824.parquet has no heat pump columns.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'Gasgebruik' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitsgebruikBooster' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-01-05 16:00:00 (1672934400.0) in 'ReadingDate' for column 'Gasgebruik'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-07-01 06:00:00 (1688191200.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Column 'ElektriciteitsgebruikWarmtepomp' in group has less than 90.0% non-NA values.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 02:00:00 > allowed (0 days 01:00:00) starting at 2023-07-01 06:00:00 (1688191200.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:9/13bdb9310675508db0e411a38d5e7824.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# ...
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'Gasgebruik' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitsgebruikWTW' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitsgebruikBooster' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'TemperatuurWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'TemperatuurWoonkamer' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'WarmteproductieWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'WatergebruikWarmTapwater' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'Luchtvochtigheid' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 19:00:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'Gasgebruik'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 19:00:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWTW'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Column 'ElektriciteitsgebruikWarmtepomp' in group has less than 90.0% non-NA values.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'WarmteproductieWarmtepomp'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 19:00:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'WatergebruikWarmTapwater'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Group has a gap of 0 days 18:30:00 > allowed (0 days 01:00:00) starting at 2023-02-15 09:00:00 (1676451600.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:193/fd27ad16fc69ea791e2d3f59ac10d722.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'ElektriciteitsgebruikWTW' in group has less than 90.0% non-NA values.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'WarmteproductieWarmtepomp' in group has less than 90.0% non-NA values.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Column 'WatergebruikWarmTapwater' in group has less than 90.0% non-NA values.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Group has a gap of 0 days 01:20:00 > allowed (0 days 01:00:00) starting at 2023-06-23 01:45:00 (1687484700.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:194/ff683b8674e0c88146abc0b5caeb1e84.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting netverbruik P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Piekbelasting teruglevering P1 [kW]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp binnen [kWh]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Vermogen warmtepomp buiten [kW]']: At least one is not available in the DataFrame.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitNetgebruikHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitNetgebruikLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitTerugleveringHoog' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitTerugleveringLaag' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitsgebruikWarmtepomp' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitsgebruikBoilervat' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'Zon-opwekMomentaan' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'Zon-opwekTotaal' has type 'float64' but expected type is 'Float64'. Coercing type.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikHoog'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitNetgebruikLaag'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringHoog'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitTerugleveringLaag'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'Gasgebruik' in group has less than 90.0% non-NA values.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'ElektriciteitsgebruikWTW' in group has less than 90.0% non-NA values.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'ElektriciteitsgebruikWarmtepomp'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'WarmteproductieWarmtepomp' in group has less than 90.0% non-NA values.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Column 'WatergebruikWarmTapwater' in group has less than 90.0% non-NA values.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Group has a gap of 0 days 01:05:00 > allowed (0 days 01:00:00) starting at 2023-10-29 02:00:00 (1698544800.0) in 'ReadingDate' for column 'Zon-opwekTotaal'.
# WARNING:root:195/ff7cfab095412abd69f4f775a3b37ba6.parquet: Some cumulative columns did not pass validation (['max_delta_allowed', 'enough_values']). Keeping group/data.
# WARNING:root:Cannot validate columns ['WarmteproductieWarmtepomp', 'WarmteproductieWarmTapwater']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 1 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 CO2 [ppm]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Luchtvochtigheid [%]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH 2 Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['CDR-RH Temperatuur [grC]']: At least one is not available in the DataFrame.
# WARNING:root:Cannot validate columns ['Mode']: At least one is not available in the DataFrame.

# %% [markdown]
# ### Check the mapped data index and statistics
#
# We can now load the mapped data and check the statisitcs. In this example, we leverage multi-processing and set the number of works to the number of CPU cores to speed up the operation.

# %%
index_df, index_path = etdmap.index_helpers.read_index()

index_df.head()
# Out:
#                   HuisIdLeverancier  HuisIdBSV ProjectIdLeverancier  \
# 0  024b35f544c0de4c78fbfa4b401126dc          1                 <NA>
# 1  0290e5ebef786f7d3937c6ea53f9ef56          2                 <NA>
# 2  068690b7864a3d0feff39bea2e5556df          3                 <NA>
# 3  08552726673ae0cb8ec73be7e4a75f9d          4                 <NA>
# 4  0bf7095bf31ef4edc72e1e8353e68dbf          5                 <NA>
#
#    ProjectIdBSV Dataleverancier  Meenemen Notities  \
# 0          <NA>         Watch-E      <NA>     <NA>
# 1          <NA>         Watch-E      <NA>     <NA>
# 2          <NA>         Watch-E      <NA>     <NA>
# 3          <NA>         Watch-E      <NA>     <NA>
# 4          <NA>         Watch-E      <NA>     <NA>
#
#    validate_monitoring_data_counts  validate_energiegebruik_warmteopwekker  \
# 0                             True                                    True
# 1                             True                                    True
# 2                             True                                    True
# 3                             True                                    True
# 4                             True                                    True
#
#    validate_approximately_one_year_of_records  ...  \
# 0                                        True  ...
# 1                                        True  ...
# 2                                        True  ...
# 3                                        True  ...
# 4                                        True  ...
#
#    validate_ElektriciteitsgebruikBoilervatDiff  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    validate_ElektriciteitsgebruikRadiator  \
# 0                                    <NA>
# 1                                    <NA>
# 2                                    <NA>
# 3                                    <NA>
# 4                                    <NA>
#
#    validate_ElektriciteitsgebruikRadiatorDiff  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    validate_WarmteproductieWarmtepomp  validate_WarmteproductieWarmtepompDiff  \
# 0                                True                                    True
# 1                                True                                    True
# 2                                True                                    True
# 3                                True                                    True
# 4                                True                                   False
#
#    validate_WatergebruikWarmTapwater  validate_WatergebruikWarmTapwaterDiff  \
# 0                               True                                   True
# 1                               True                                   True
# 2                               True                                   True
# 3                               True                                   True
# 4                               True                                   True
#
#    validate_Zon-opwekTotaal  validate_Zon-opwekTotaalDiff  \
# 0                      <NA>                          True
# 1                      <NA>                          True
# 2                      <NA>                          True
# 3                      <NA>                          True
# 4                      <NA>                          True
#
#    validate_cumulative_diff_ok
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                        False
#
# [5 rows x 39 columns]

# %% [markdown]
# We can see a few columns are not yet defined. Such as the project ids and whether we want to include the data in our aggregate datasets (column `Meenemen`).
#
# These metadata will be manually added in a later step.

# %%
mapped_data_summary_df = mapping_helpers.get_mapped_data_stats(multi = False)

# %%
mapped_data_summary_df.head()
# Out:
#    HuisIdBSV                          column            type   count  missing  \
# 0          1                     ReadingDate  datetime64[ns]  105121        0
# 1          1     ElektriciteitNetgebruikHoog         Float64  105093       28
# 2          1     ElektriciteitNetgebruikLaag         Float64  105093       28
# 3          1  ElektriciteitTerugleveringHoog         Float64  105093       28
# 4          1  ElektriciteitTerugleveringLaag         Float64  105093       28
#
#    errors                  min                  max         mean    median  \
# 0       0  2023-01-01 00:00:00  2024-01-01 00:00:00          NaN       NaN
# 1      28               822.16             1364.201  1077.002484  1067.561
# 2      28              1157.82             1985.089  1558.287115  1564.534
# 3      28              3397.66             5960.516  4755.762583  4830.055
# 4      28              2268.15             3382.208  2862.596044  2949.556
#
#    ...  validate_ElektriciteitsgebruikBoilervatDiff  \
# 0  ...                                         True
# 1  ...                                         True
# 2  ...                                         True
# 3  ...                                         True
# 4  ...                                         True
#
#    validate_ElektriciteitsgebruikRadiator  \
# 0                                    <NA>
# 1                                    <NA>
# 2                                    <NA>
# 3                                    <NA>
# 4                                    <NA>
#
#    validate_ElektriciteitsgebruikRadiatorDiff  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#   validate_WarmteproductieWarmtepomp validate_WarmteproductieWarmtepompDiff  \
# 0                               True                                   True
# 1                               True                                   True
# 2                               True                                   True
# 3                               True                                   True
# 4                               True                                   True
#
#   validate_WatergebruikWarmTapwater  validate_WatergebruikWarmTapwaterDiff  \
# 0                              True                                   True
# 1                              True                                   True
# 2                              True                                   True
# 3                              True                                   True
# 4                              True                                   True
#
#   validate_Zon-opwekTotaal  validate_Zon-opwekTotaalDiff  \
# 0                     <NA>                          True
# 1                     <NA>                          True
# 2                     <NA>                          True
# 3                     <NA>                          True
# 4                     <NA>                          True
#
#   validate_cumulative_diff_ok
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
#
# [5 rows x 52 columns]

# %%
mapped_data_summary_df[mapped_data_summary_df['missing']>0].head()
# Out:
#    HuisIdBSV                          column     type   count  missing  \
# 1          1     ElektriciteitNetgebruikHoog  Float64  105093       28
# 2          1     ElektriciteitNetgebruikLaag  Float64  105093       28
# 3          1  ElektriciteitTerugleveringHoog  Float64  105093       28
# 4          1  ElektriciteitTerugleveringLaag  Float64  105093       28
# 5          1           ElektriciteitVermogen  float64       0   105121
#
#    errors      min       max         mean    median  ...  \
# 1      28   822.16  1364.201  1077.002484  1067.561  ...
# 2      28  1157.82  1985.089  1558.287115  1564.534  ...
# 3      28  3397.66  5960.516  4755.762583  4830.055  ...
# 4      28  2268.15  3382.208  2862.596044  2949.556  ...
# 5  105121     None      None          NaN       NaN  ...
#
#    validate_ElektriciteitsgebruikBoilervatDiff  \
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# 5                                         True
#
#    validate_ElektriciteitsgebruikRadiator  \
# 1                                    <NA>
# 2                                    <NA>
# 3                                    <NA>
# 4                                    <NA>
# 5                                    <NA>
#
#    validate_ElektriciteitsgebruikRadiatorDiff  \
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# 5                                        True
#
#   validate_WarmteproductieWarmtepomp validate_WarmteproductieWarmtepompDiff  \
# 1                               True                                   True
# 2                               True                                   True
# 3                               True                                   True
# 4                               True                                   True
# 5                               True                                   True
#
#   validate_WatergebruikWarmTapwater  validate_WatergebruikWarmTapwaterDiff  \
# 1                              True                                   True
# 2                              True                                   True
# 3                              True                                   True
# 4                              True                                   True
# 5                              True                                   True
#
#   validate_Zon-opwekTotaal  validate_Zon-opwekTotaalDiff  \
# 1                     <NA>                          True
# 2                     <NA>                          True
# 3                     <NA>                          True
# 4                     <NA>                          True
# 5                     <NA>                          True
#
#   validate_cumulative_diff_ok
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# 5                        True
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Add data processor metadata
#
# At this point, we will want to decide which households can be included in our final mapped dataset and also group them by project. To do this we must manually create the data processor metadata that should also help to anonymize the household data by not using the data supplier project id.
#
# To do this, we will first change our configuration to point to the new filled in metadata file.
#
# ```mermaid
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
# sequenceDiagram
#     participant Supplier
#     participant DataProcessorBSV
#
#     DataProcessorBSV->DataProcessorBSV: Final statistical column check <br>`get_mapped_data_stats()`
#     Note right of DataProcessorBSV: Send feedback if needed
#
#     DataProcessorBSV-->Supplier: Feedback to revise data
#
#     Supplier->Supplier: Revise data & resubmit
#
#     Supplier->DataProcessorBSV: Submit revised data
#
#     DataProcessorBSV->DataProcessorBSV: Update BSV metadata <br>`update_index()`, <br>`add_supplier_metadata_to_index()`
#     DataProcessorBSV->DataProcessorBSV: Manage data index & aggregate data
#     DataProcessorBSV-->Supplier: Process complete
# ```

# %%
etdmap.options.bsv_metadata_file = "../../demodata/bsv_metadata_after_mapping.xlsx" # change to path to the Excel file with the data processor metadata (BSV is the data processor in this case)

# %%
import pandas as pd

bsv_metadata_df = pd.read_excel(etdmap.options.bsv_metadata_file)
bsv_metadata_df.head()

bsv_metadata_df[bsv_metadata_df["Meenemen"] == False][['HuisIdBSV', 'Notities']].head()
# Out:
#      HuisIdBSV                                           Notities
# 38          45  Missing the first two months of the year (in r...
# 45          52  Missing the first two months of the year (in r...
# 67          76  Missing the first two months of the year (in r...
# 119        133  Missing the first two months of the year (in r...
# 152        170  Missing the first two months of the year (in r...

# %% [markdown]
# At this point we are finished with the mapping. The next steps are to aggregate the data we have chosen to include (`Meenemen == True`). This is demonstrated in the transformation notebook.
